# %%
import numpy as np
import pandas as pd

# %%
data = {'Classe': ['junior', 'junior', 'pleno', 'pleno', 'senior', 'senior'], 
      'nome': ['João', 'Maria', 'José', 'Ana', 'Carlos', 'Lucas'],
      'venda': [1000, 2000, 3000, 4000, 5000, 6000]}

# %%
df = pd.DataFrame(data)
df
# Out:
#    Classe    nome  venda
# 0  junior    João   1000
# 1  junior   Maria   2000
# 2   pleno    José   3000
# 3   pleno     Ana   4000
# 4  senior  Carlos   5000
# 5  senior   Lucas   6000

# %%
df.groupby('Classe')['venda'].mean()
# Out:
# Classe
# junior    1500.0
# pleno     3500.0
# senior    5500.0
# Name: venda, dtype: float64

# %%
df.groupby('Classe').min()
# Out:
#           nome  venda
# Classe
# junior    João   1000
# pleno      Ana   3000
# senior  Carlos   5000

# %%
df2 = df.copy()

# %%
df2["venda"] = [1000, 5000, 3000, 2000, 5300, 7000]

# %%
df2
# Out:
#    Classe    nome  venda
# 0  junior    João   1000
# 1  junior   Maria   5000
# 2   pleno    José   3000
# 3   pleno     Ana   2000
# 4  senior  Carlos   5300
# 5  senior   Lucas   7000

# %%
df3 = pd.concat([df, df2])
df3
# Out:
#    Classe    nome  venda
# 0  junior    João   1000
# 1  junior   Maria   2000
# 2   pleno    José   3000
# 3   pleno     Ana   4000
# 4  senior  Carlos   5000
# 5  senior   Lucas   6000
# 0  junior    João   1000
# 1  junior   Maria   5000
# 2   pleno    José   3000
# 3   pleno     Ana   2000
# 4  senior  Carlos   5300
# 5  senior   Lucas   7000

# %%
df.groupby(['Classe', 'nome']).sum()
# Out:
#                venda
# Classe nome
# junior João     1000
#        Maria    2000
# pleno  Ana      4000
#        José     3000
# senior Carlos   5000
#        Lucas    6000
